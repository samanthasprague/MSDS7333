# %% [markdown]
# # Unit 12 -- Neural Network using Tensorflow
#
# *Python Version*

# %%
import sys
print(sys.version)

# %% [markdown]
# *Import Libraries*
# **Tensorflow
# Pandas
# sklearn
# numpy
# keras**

# %%
import tensorflow as tf
#from tensorflow.keras import layers

from sklearn import datasets
import pandas as pd
import numpy as np
from tensorflow.keras import layers
print(tf.__version__)

import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)
# Out:
# 2.0.0

# %% [markdown]
# ## Load the Data
# *Higgs Data*

# %%
df = pd.read_csv('HIGGS.csv', header=None)

# %%
# Verify size is as expected
print("{:>25}{:>10,} x {:,}\n".format("Shape of raw data is ", df.shape[0], df.shape[1]))
# Out:
#     Shape of raw data is 11,000,000 x 29

# %% [markdown]
# The size of the HIGGS.csv file contains 11,000,000 records and 29 featues. On the paper "Searching for Exotic Particles" they resample the data and used a 2.6 million records to do the training of the model and 100,000 samples to validate the model.
# To start building the process we will take a sample of 50,000 records and 5000 for validation. Then we would increase the sample to the level used on the paper.
#
# Column '0' is the target value the rest of the columns (1-28) the rest of the features.

# %%
df.head()
# Out:
#     0         1         2         3         4         5         6         7   \
# 0  1.0  0.869293 -0.635082  0.225690  0.327470 -0.689993  0.754202 -0.248573
# 1  1.0  0.907542  0.329147  0.359412  1.497970 -0.313010  1.095531 -0.557525
# 2  1.0  0.798835  1.470639 -1.635975  0.453773  0.425629  1.104875  1.282322
# 3  0.0  1.344385 -0.876626  0.935913  1.992050  0.882454  1.786066 -1.646778
# 4  1.0  1.105009  0.321356  1.522401  0.882808 -1.205349  0.681466 -1.070464
#
#          8         9   ...        19        20        21        22        23  \
# 0 -1.092064  0.000000  ... -0.010455 -0.045767  3.101961  1.353760  0.979563
# 1 -1.588230  2.173076  ... -1.138930 -0.000819  0.000000  0.302220  0.833048
# 2  1.381664  0.000000  ...  1.128848  0.900461  0.000000  0.909753  1.108330
# 3 -0.942383  0.000000  ... -0.678379 -1.360356  0.000000  0.946652  1.028704
# 4 -0.921871  0.000000  ... -0.373566  0.113041  0.000000  0.755856  1.361057
#
#          24        25        26        27        28
# 0  0.978076  0.920005  0.721657  0.988751  0.876678
# 1  0.985700  0.978098  0.779732  0.992356  0.798343
# 2  0.985692  0.951331  0.803252  0.865924  0.780118
# 3  0.998656  0.728281  0.869200  1.026736  0.957904
# 4  0.986610  0.838085  1.133295  0.872245  0.808487
#
# [5 rows x 29 columns]

# %% [markdown]
# **Select a sample of 50,000 for training**

# %%
nSamples=500000
train_set = df.sample(n=nSamples, random_state=99)

# %%
train_set.shape
# Out:
# (500000, 29)

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
train_set[0].hist()
plt.show()

# %% [markdown]
# **Select a sample of 5,000 from the remaining data as validation**

# %%
test_set = df[~df.isin(train_set)].dropna().sample(n=50000, random_state=99)

# %%
test_set.shape
# Out:
# (50000, 29)

# %%
test_set[0].hist()
plt.show()

# %% [markdown]
# ## Model

# %%
model = tf.keras.Sequential()

#Input Layer
model.add(layers.Dense(28, input_dim = 28))
# Hidden Layers
model.add(layers.Dense(300, activation = 'tanh'))
model.add(layers.Dense(300, activation = 'tanh'))
model.add(layers.Dense(300, activation = 'tanh'))
#outputLayer
model.add(layers.Dense(1, activation='sigmoid'))

# %% [markdown]
# ## Compilation

# %%
# For a binary classification problem
model.compile(optimizer='adam',
              loss='binary_crossentropy',
              metrics=['accuracy'])

# %% [markdown]
# ## Training

# %%
from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler(feature_range=(0,1))
scaled_train = scaler.fit_transform( train_set.iloc[:, 1:])

# Print out the adjustment that the scaler applied to the total_earnings column of data
print("Note: median values were scaled by multiplying by {:.10f} and adding {:.6f}".format(scaler.scale_[12],scaler.min_[12]))
multiplied_by = scaler.scale_[12]
added = scaler.min_[12]

scaled_train_df = pd.DataFrame(scaled_train, columns =  train_set.iloc[:, 1:].columns.values)
# Out:
# Note: median values were scaled by multiplying by 0.4514933346 and adding 0.000000

# %%
for i in scaled_train_df:
    scaled_train_df[i].hist()
    plt.show()

# %%
X_train = scaled_train_df.values
Y_train = train_set.iloc[:, 0].values

# %%
X_train
# Out:
# array([[0.00570078, 0.7138    , 0.56018523, ..., 0.05591448, 0.13171565,
#         0.21752973],
#        [0.04230581, 0.64599999, 0.70360655, ..., 0.05310746, 0.07705583,
#         0.08600733],
#        [0.12447961, 0.66879999, 0.68354985, ..., 0.10186449, 0.10035701,
#         0.15880375],
#        ...,
#        [0.0105202 , 0.05200002, 0.82856296, ..., 0.07465703, 0.05323631,
#         0.05375624],
#        [0.08453662, 0.01920002, 0.68370904, ..., 0.06308635, 0.08315559,
#         0.08273984],
#        [0.04127442, 0.65999999, 0.51991265, ..., 0.02308429, 0.05466851,
#         0.05137527]])

# %%
history = model.fit(X_train,Y_train, validation_split=0.10, epochs=100, batch_size=1000, verbose=1)
# Out:
# Train on 450000 samples, validate on 50000 samples
# Epoch 1/100
# 450000/450000 [==============================] - 6s 13us/sample - loss: 0.6570 - accuracy: 0.6036 - val_loss: 0.6422 - val_accuracy: 0.6300
# Epoch 2/100
# 450000/450000 [==============================] - 5s 11us/sample - loss: 0.6440 - accuracy: 0.6259 - val_loss: 0.6393 - val_accuracy: 0.6343
# Epoch 3/100
# 450000/450000 [==============================] - 5s 11us/sample - loss: 0.6414 - accuracy: 0.6310 - val_loss: 0.6436 - val_accuracy: 0.6248
# Epoch 4/100
# 450000/450000 [==============================] - 5s 11us/sample - loss: 0.6381 - accuracy: 0.6350 - val_loss: 0.6343 - val_accuracy: 0.6362
# Epoch 5/100
# 450000/450000 [==============================] - 5s 11us/sample - loss: 0.6217 - accuracy: 0.6507 - val_loss: 0.6131 - val_accuracy: 0.6650
# Epoch 6/100
# 450000/450000 [==============================] - 5s 12us/sample - loss: 0.6052 - accuracy: 0.6702 - val_loss: 0.6013 - val_accuracy: 0.6722
# Epoch 7/100
# 450000/450000 [==============================] - 5s 11us/sample - loss: 0.5982 - accuracy: 0.6757 - val_loss: 0.5932 - val_accuracy: 0.6804
# Epoch 8/100
# 450000/450000 [==============================] - 5s 12us/sample - loss: 0.5887 - accuracy: 0.6844 - val_loss: 0.5980 - val_accuracy: 0.6755
# Epoch 9/100
# 450000/450000 [==============================] - 5s 11us/sample - loss: 0.5794 - accuracy: 0.6927 - val_loss: 0.5783 - val_accuracy: 0.6947
# Epoch 10/100
# 450000/450000 [==============================] - 5s 11us/sample - loss: 0.5734 - accuracy: 0.6971 - val_loss: 0.5712 - val_accuracy: 0.6992
# Epoch 11/100
# 450000/450000 [==============================] - 5s 11us/sample - loss: 0.5689 - accuracy: 0.7013 - val_loss: 0.5684 - val_accuracy: 0.7001
# Epoch 12/100
# 450000/450000 [==============================] - 5s 12us/sample - loss: 0.5651 - accuracy: 0.7044 - val_loss: 0.5657 - val_accuracy: 0.7034
# Epoch 13/100
# 450000/450000 [==============================] - 5s 12us/sample - loss: 0.5626 - accuracy: 0.7059 - val_loss: 0.5662 - val_accuracy: 0.7039
# Epoch 14/100
# 450000/450000 [==============================] - 5s 11us/sample - loss: 0.5580 - accuracy: 0.7099 - val_loss: 0.5594 - val_accuracy: 0.7094
# Epoch 15/100
# 450000/450000 [==============================] - 5s 11us/sample - loss: 0.5545 - accuracy: 0.7121 - val_loss: 0.5518 - val_accuracy: 0.7139
# Epoch 16/100
# 450000/450000 [==============================] - 5s 12us/sample - loss: 0.5518 - accuracy: 0.7144 - val_loss: 0.5525 - val_accuracy: 0.7134
# Epoch 17/100
# 450000/450000 [==============================] - 5s 12us/sample - loss: 0.5500 - accuracy: 0.7150 - val_loss: 0.5494 - val_accuracy: 0.7173
# Epoch 18/100
# 450000/450000 [==============================] - 5s 12us/sample - loss: 0.5480 - accuracy: 0.7169 - val_loss: 0.5477 - val_accuracy: 0.7182
# Epoch 19/100
# 450000/450000 [==============================] - 5s 12us/sample - loss: 0.5468 - accuracy: 0.7181 - val_loss: 0.5418 - val_accuracy: 0.7212
# Epoch 20/100
# 450000/450000 [==============================] - 5s 12us/sample - loss: 0.5444 - accuracy: 0.7201 - val_loss: 0.5441 - val_accuracy: 0.7208
# Epoch 21/100
# 450000/450000 [==============================] - 5s 12us/sample - loss: 0.5425 - accuracy: 0.7208 - val_loss: 0.5453 - val_accuracy: 0.7195
# Epoch 22/100
# 450000/450000 [==============================] - 5s 12us/sample - loss: 0.5418 - accuracy: 0.7213 - val_loss: 0.5457 - val_accuracy: 0.7210
# Epoch 23/100
# 450000/450000 [==============================] - 5s 12us/sample - loss: 0.5401 - accuracy: 0.7228 - val_loss: 0.5456 - val_accuracy: 0.7217
# Epoch 24/100
# 450000/450000 [==============================] - 5s 12us/sample - loss: 0.5385 - accuracy: 0.7242 - val_loss: 0.5404 - val_accuracy: 0.7225
# Epoch 25/100
# 450000/450000 [==============================] - 5s 12us/sample - loss: 0.5372 - accuracy: 0.7244 - val_loss: 0.5395 - val_accuracy: 0.7252
# Epoch 26/100
# 450000/450000 [==============================] - 5s 12us/sample - loss: 0.5355 - accuracy: 0.7259 - val_loss: 0.5356 - val_accuracy: 0.7261
# Epoch 27/100
# 450000/450000 [==============================] - 5s 12us/sample - loss: 0.5347 - accuracy: 0.7268 - val_loss: 0.5377 - val_accuracy: 0.7244
# Epoch 28/100
# 450000/450000 [==============================] - 5s 12us/sample - loss: 0.5331 - accuracy: 0.7281 - val_loss: 0.5358 - val_accuracy: 0.7254
# Epoch 29/100
# 450000/450000 [==============================] - 5s 12us/sample - loss: 0.5306 - accuracy: 0.7298 - val_loss: 0.5324 - val_accuracy: 0.7292
# Epoch 30/100
# 450000/450000 [==============================] - 5s 12us/sample - loss: 0.5293 - accuracy: 0.7307 - val_loss: 0.5351 - val_accuracy: 0.7269
# Epoch 31/100
# 450000/450000 [==============================] - 5s 12us/sample - loss: 0.5276 - accuracy: 0.7320 - val_loss: 0.5268 - val_accuracy: 0.7322
# Epoch 32/100
# 450000/450000 [==============================] - 5s 12us/sample - loss: 0.5247 - accuracy: 0.7338 - val_loss: 0.5281 - val_accuracy: 0.7324
# Epoch 33/100
# 450000/450000 [==============================] - 5s 12us/sample - loss: 0.5221 - accuracy: 0.7351 - val_loss: 0.5269 - val_accuracy: 0.7307
# Epoch 34/100
# 450000/450000 [==============================] - 5s 12us/sample - loss: 0.5210 - accuracy: 0.7367 - val_loss: 0.5235 - val_accuracy: 0.7335
# Epoch 35/100
# 450000/450000 [==============================] - 5s 12us/sample - loss: 0.5203 - accuracy: 0.7367 - val_loss: 0.5271 - val_accuracy: 0.7310
# Epoch 36/100
# 450000/450000 [==============================] - 5s 12us/sample - loss: 0.5168 - accuracy: 0.7389 - val_loss: 0.5183 - val_accuracy: 0.7377
# Epoch 37/100
# 450000/450000 [==============================] - 5s 12us/sample - loss: 0.5173 - accuracy: 0.7386 - val_loss: 0.5180 - val_accuracy: 0.7376
# Epoch 38/100
# 450000/450000 [==============================] - 5s 12us/sample - loss: 0.5150 - accuracy: 0.7406 - val_loss: 0.5216 - val_accuracy: 0.7373
# Epoch 39/100
# 450000/450000 [==============================] - 5s 12us/sample - loss: 0.5141 - accuracy: 0.7412 - val_loss: 0.5224 - val_accuracy: 0.7361
# Epoch 40/100
# 450000/450000 [==============================] - 5s 12us/sample - loss: 0.5133 - accuracy: 0.7416 - val_loss: 0.5230 - val_accuracy: 0.7349
# Epoch 41/100
# 450000/450000 [==============================] - 5s 12us/sample - loss: 0.5120 - accuracy: 0.7430 - val_loss: 0.5142 - val_accuracy: 0.7405
# Epoch 42/100
# 450000/450000 [==============================] - 5s 12us/sample - loss: 0.5109 - accuracy: 0.7438 - val_loss: 0.5172 - val_accuracy: 0.7393
# Epoch 43/100
# 450000/450000 [==============================] - 5s 12us/sample - loss: 0.5101 - accuracy: 0.7435 - val_loss: 0.5180 - val_accuracy: 0.7373
# Epoch 44/100
# 450000/450000 [==============================] - 5s 12us/sample - loss: 0.5090 - accuracy: 0.7448 - val_loss: 0.5132 - val_accuracy: 0.7403
# Epoch 45/100
# 450000/450000 [==============================] - 5s 12us/sample - loss: 0.5087 - accuracy: 0.7453 - val_loss: 0.5203 - val_accuracy: 0.7366
# Epoch 46/100
# 450000/450000 [==============================] - 5s 12us/sample - loss: 0.5066 - accuracy: 0.7461 - val_loss: 0.5141 - val_accuracy: 0.7410
# Epoch 47/100
# 450000/450000 [==============================] - 5s 12us/sample - loss: 0.5061 - accuracy: 0.7459 - val_loss: 0.5136 - val_accuracy: 0.7404
# Epoch 48/100
# 450000/450000 [==============================] - 5s 12us/sample - loss: 0.5051 - accuracy: 0.7478 - val_loss: 0.5138 - val_accuracy: 0.7412
# Epoch 49/100
# 450000/450000 [==============================] - 5s 12us/sample - loss: 0.5040 - accuracy: 0.7485 - val_loss: 0.5109 - val_accuracy: 0.7426
# Epoch 50/100
# 450000/450000 [==============================] - 5s 12us/sample - loss: 0.5023 - accuracy: 0.7491 - val_loss: 0.5123 - val_accuracy: 0.7427
# Epoch 51/100
# 450000/450000 [==============================] - 5s 12us/sample - loss: 0.5020 - accuracy: 0.7494 - val_loss: 0.5120 - val_accuracy: 0.7427
# Epoch 52/100
# 450000/450000 [==============================] - 5s 12us/sample - loss: 0.5005 - accuracy: 0.7505 - val_loss: 0.5135 - val_accuracy: 0.7413
# Epoch 53/100
# 450000/450000 [==============================] - 5s 12us/sample - loss: 0.4995 - accuracy: 0.7515 - val_loss: 0.5128 - val_accuracy: 0.7410
# Epoch 54/100
# 450000/450000 [==============================] - 5s 12us/sample - loss: 0.4992 - accuracy: 0.7514 - val_loss: 0.5094 - val_accuracy: 0.7439
# Epoch 55/100
# 450000/450000 [==============================] - 5s 11us/sample - loss: 0.4973 - accuracy: 0.7524 - val_loss: 0.5114 - val_accuracy: 0.7424
# Epoch 56/100
# 450000/450000 [==============================] - 6s 13us/sample - loss: 0.4972 - accuracy: 0.7532 - val_loss: 0.5128 - val_accuracy: 0.7427
# Epoch 57/100
# 450000/450000 [==============================] - 5s 12us/sample - loss: 0.4957 - accuracy: 0.7538 - val_loss: 0.5146 - val_accuracy: 0.7408
# Epoch 58/100
# 450000/450000 [==============================] - 5s 12us/sample - loss: 0.4945 - accuracy: 0.7548 - val_loss: 0.5110 - val_accuracy: 0.7428
# Epoch 59/100
# 450000/450000 [==============================] - 5s 12us/sample - loss: 0.4934 - accuracy: 0.7556 - val_loss: 0.5128 - val_accuracy: 0.7421
# Epoch 60/100
# 450000/450000 [==============================] - 5s 12us/sample - loss: 0.4928 - accuracy: 0.7561 - val_loss: 0.5069 - val_accuracy: 0.7465
# Epoch 61/100
# 450000/450000 [==============================] - 5s 12us/sample - loss: 0.4920 - accuracy: 0.7559 - val_loss: 0.5127 - val_accuracy: 0.7423
# Epoch 62/100
# 450000/450000 [==============================] - 5s 12us/sample - loss: 0.4912 - accuracy: 0.7567 - val_loss: 0.5105 - val_accuracy: 0.7426
# Epoch 63/100
# 450000/450000 [==============================] - 5s 12us/sample - loss: 0.4903 - accuracy: 0.7567 - val_loss: 0.5100 - val_accuracy: 0.7434
# Epoch 64/100
# 450000/450000 [==============================] - 5s 12us/sample - loss: 0.4887 - accuracy: 0.7583 - val_loss: 0.5101 - val_accuracy: 0.7435
# Epoch 65/100
# 450000/450000 [==============================] - 5s 12us/sample - loss: 0.4879 - accuracy: 0.7589 - val_loss: 0.5133 - val_accuracy: 0.7414
# Epoch 66/100
# 450000/450000 [==============================] - 5s 12us/sample - loss: 0.4873 - accuracy: 0.7593 - val_loss: 0.5133 - val_accuracy: 0.7424
# Epoch 67/100
# 450000/450000 [==============================] - 5s 12us/sample - loss: 0.4858 - accuracy: 0.7605 - val_loss: 0.5106 - val_accuracy: 0.7448
# Epoch 68/100
# 450000/450000 [==============================] - 5s 12us/sample - loss: 0.4846 - accuracy: 0.7615 - val_loss: 0.5113 - val_accuracy: 0.7431
# Epoch 69/100
# 450000/450000 [==============================] - 5s 12us/sample - loss: 0.4838 - accuracy: 0.7621 - val_loss: 0.5111 - val_accuracy: 0.7442
# Epoch 70/100
# 450000/450000 [==============================] - 5s 12us/sample - loss: 0.4829 - accuracy: 0.7623 - val_loss: 0.5128 - val_accuracy: 0.7436
# Epoch 71/100
# 450000/450000 [==============================] - 5s 12us/sample - loss: 0.4817 - accuracy: 0.7631 - val_loss: 0.5135 - val_accuracy: 0.7415
# Epoch 72/100
# 450000/450000 [==============================] - 5s 11us/sample - loss: 0.4808 - accuracy: 0.7634 - val_loss: 0.5193 - val_accuracy: 0.7404
# Epoch 73/100
# 450000/450000 [==============================] - 5s 12us/sample - loss: 0.4796 - accuracy: 0.7647 - val_loss: 0.5105 - val_accuracy: 0.7463
# Epoch 74/100
# 450000/450000 [==============================] - 5s 11us/sample - loss: 0.4795 - accuracy: 0.7650 - val_loss: 0.5096 - val_accuracy: 0.7454
# Epoch 75/100
# 450000/450000 [==============================] - 5s 11us/sample - loss: 0.4777 - accuracy: 0.7662 - val_loss: 0.5093 - val_accuracy: 0.7464
# Epoch 76/100
# 450000/450000 [==============================] - 5s 11us/sample - loss: 0.4768 - accuracy: 0.7662 - val_loss: 0.5152 - val_accuracy: 0.7423
# Epoch 77/100
# 450000/450000 [==============================] - 5s 12us/sample - loss: 0.4762 - accuracy: 0.7671 - val_loss: 0.5151 - val_accuracy: 0.7432
# Epoch 78/100
# 450000/450000 [==============================] - 5s 11us/sample - loss: 0.4750 - accuracy: 0.7674 - val_loss: 0.5123 - val_accuracy: 0.7439
# Epoch 79/100
# 450000/450000 [==============================] - 5s 11us/sample - loss: 0.4739 - accuracy: 0.7681 - val_loss: 0.5124 - val_accuracy: 0.7443
# Epoch 80/100
# 450000/450000 [==============================] - 5s 11us/sample - loss: 0.4729 - accuracy: 0.7688 - val_loss: 0.5133 - val_accuracy: 0.7439
# Epoch 81/100
# 450000/450000 [==============================] - 5s 12us/sample - loss: 0.4716 - accuracy: 0.7696 - val_loss: 0.5129 - val_accuracy: 0.7450
# Epoch 82/100
# 450000/450000 [==============================] - 5s 12us/sample - loss: 0.4708 - accuracy: 0.7706 - val_loss: 0.5130 - val_accuracy: 0.7450
# Epoch 83/100
# 450000/450000 [==============================] - 5s 11us/sample - loss: 0.4703 - accuracy: 0.7705 - val_loss: 0.5141 - val_accuracy: 0.7455
# Epoch 84/100
# 450000/450000 [==============================] - 5s 12us/sample - loss: 0.4693 - accuracy: 0.7710 - val_loss: 0.5155 - val_accuracy: 0.7440
# Epoch 85/100
# 450000/450000 [==============================] - 5s 12us/sample - loss: 0.4683 - accuracy: 0.7721 - val_loss: 0.5186 - val_accuracy: 0.7414
# Epoch 86/100
# 450000/450000 [==============================] - 5s 12us/sample - loss: 0.4673 - accuracy: 0.7727 - val_loss: 0.5162 - val_accuracy: 0.7421
# Epoch 87/100
# 450000/450000 [==============================] - 5s 12us/sample - loss: 0.4664 - accuracy: 0.7731 - val_loss: 0.5168 - val_accuracy: 0.7417
# Epoch 88/100
# 450000/450000 [==============================] - 5s 11us/sample - loss: 0.4649 - accuracy: 0.7746 - val_loss: 0.5199 - val_accuracy: 0.7415
# Epoch 89/100
# 450000/450000 [==============================] - 5s 12us/sample - loss: 0.4643 - accuracy: 0.7748 - val_loss: 0.5191 - val_accuracy: 0.7421
# Epoch 90/100
# 450000/450000 [==============================] - 5s 12us/sample - loss: 0.4634 - accuracy: 0.7753 - val_loss: 0.5199 - val_accuracy: 0.7432
# Epoch 91/100
# 450000/450000 [==============================] - 5s 11us/sample - loss: 0.4630 - accuracy: 0.7759 - val_loss: 0.5174 - val_accuracy: 0.7447
# Epoch 92/100
# 450000/450000 [==============================] - 5s 12us/sample - loss: 0.4614 - accuracy: 0.7765 - val_loss: 0.5226 - val_accuracy: 0.7403
# Epoch 93/100
# 450000/450000 [==============================] - 5s 12us/sample - loss: 0.4611 - accuracy: 0.7770 - val_loss: 0.5206 - val_accuracy: 0.7398
# Epoch 94/100
# 450000/450000 [==============================] - 5s 11us/sample - loss: 0.4594 - accuracy: 0.7782 - val_loss: 0.5192 - val_accuracy: 0.7431
# Epoch 95/100
# 450000/450000 [==============================] - 5s 11us/sample - loss: 0.4591 - accuracy: 0.7785 - val_loss: 0.5234 - val_accuracy: 0.7397
# Epoch 96/100
# 450000/450000 [==============================] - 5s 12us/sample - loss: 0.4588 - accuracy: 0.7782 - val_loss: 0.5226 - val_accuracy: 0.7408
# Epoch 97/100
# 450000/450000 [==============================] - 5s 11us/sample - loss: 0.4562 - accuracy: 0.7801 - val_loss: 0.5238 - val_accuracy: 0.7400
# Epoch 98/100
# 450000/450000 [==============================] - 5s 11us/sample - loss: 0.4559 - accuracy: 0.7802 - val_loss: 0.5246 - val_accuracy: 0.7393
# Epoch 99/100
# 450000/450000 [==============================] - 5s 11us/sample - loss: 0.4547 - accuracy: 0.7813 - val_loss: 0.5271 - val_accuracy: 0.7380
# Epoch 100/100
# 450000/450000 [==============================] - 5s 12us/sample - loss: 0.4547 - accuracy: 0.7811 - val_loss: 0.5269 - val_accuracy: 0.7372

# %%
# Plot training & validation accuracy values
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()

# Plot training & validation loss values
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()

# %% [markdown]
# ## Test

# %%
scaler = MinMaxScaler(feature_range=(0,1))
scaled_train = scaler.fit_transform( test_set.iloc[:, 1:])

# Print out the adjustment that the scaler applied to the total_earnings column of data
print("Note: median values were scaled by multiplying by {:.10f} and adding {:.6f}".format(scaler.scale_[12],scaler.min_[12]))
multiplied_by = scaler.scale_[12]
added = scaler.min_[12]

scaled_test_df = pd.DataFrame(scaled_train, columns =  test_set.iloc[:, 1:].columns.values)
# Out:
# Note: median values were scaled by multiplying by 0.4514933346 and adding 0.000000

# %%
X_test = scaled_test_df.values
Y_test = test_set.iloc[:, 0].values

# %%
predictions = model.predict(X_test)

# %%
print("Prediction: {}".format(tf.argmax(predictions, axis=1)))
print("   Actuals: {}".format(Y_test))
# Out:
# Prediction: [0 0 0 ... 0 0 0]
#    Actuals: [0. 0. 1. ... 0. 1. 0.]

# %% [markdown]
# ## ROC Curves

# %%
from sklearn.metrics import roc_curve
predictions = model.predict(X_test).ravel()
fpr_keras, tpr_keras, thresholds_keras = roc_curve(Y_test, predictions)

# %% [markdown]
# **Area Under the Curve Calculation**

# %%
from sklearn.metrics import auc
auc_keras = auc(fpr_keras, tpr_keras)

# %%
plt.figure(1)
plt.plot([0, 1], [0, 1], 'k--')
plt.plot(fpr_keras, tpr_keras, label='Keras (area = {:.3f})'.format(auc_keras))
plt.xlabel('False positive rate')
plt.ylabel('True positive rate')
plt.title('ROC curve')
plt.legend(loc='best')
plt.show()

# %%
confMat=tf.math.confusion_matrix(
    Y_test,
    tf.argmax(predictions, axis=1),
    num_classes=None,
    weights=None,
    dtype=tf.dtypes.int32,
    name=None
)

# %%
print(tf.argmax(predictions, axis=1))
# Out:
# tf.Tensor([0 0 0 ... 0 0 0], shape=(50000,), dtype=int64)
